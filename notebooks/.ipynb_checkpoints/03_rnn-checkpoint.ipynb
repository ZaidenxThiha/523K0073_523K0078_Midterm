# %% [markdown]
# # 03 RNN / LSTM / GRU (Part C)
#
# This notebook handles the recurrent-model workflow: preprocessing for the sequence models, training and evaluating Vanilla RNN, LSTM, and GRU, showing performance reports in the notebook, and displaying learning-curve plots directly in the notebook. Only checkpoints are saved to disk.

# %%
from __future__ import annotations

import os
import random
import sys
import time
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from IPython.display import display
from torch import nn
from torch.utils.data import DataLoader
from tqdm.auto import tqdm

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from src.evaluate import evaluate_loader, plot_learning_curves, top_misclassified_examples
from src.preprocess import PAD_ID, UNK_ID, PAD_TOKEN, UNK_TOKEN, prepare_recurrent_data
from src.rnn_model import DynamicPadCollator, RNNClassifier, TextDataset

# %%
RANDOM_SEED = 42
MAX_LEN = 455
VOCAB_SIZES = [10000, 20000, 30000]
SELECTED_VOCAB_SIZE = 30000
BATCH_SIZE = 64
EPOCHS = 3
LEARNING_RATE = 1e-3
EMBED_DIM = 128
HIDDEN_DIM = 128
NUM_LAYERS = 1
DROPOUT = 0.5

CHECKPOINT_DIR = Path("../checkpoints")
CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(RANDOM_SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device

# %% [markdown]
# ## Preprocessing For The Recurrent Models

# %%
preprocessing = prepare_recurrent_data(
    max_len=MAX_LEN,
    vocab_sizes=VOCAB_SIZES,
    selected_vocab_size=SELECTED_VOCAB_SIZE,
    seed=RANDOM_SEED,
)

split_summary_df = preprocessing["split_summary_df"]
vocab_summary_df = preprocessing["vocab_summary_df"]
vocab = preprocessing["selected_vocab"]
encoded_splits = preprocessing["selected_encoded_splits"]

print(f"Vocabulary sizes explored: {VOCAB_SIZES}")
print(f"Vocabulary size selected for model training: {SELECTED_VOCAB_SIZE}")
vocab_summary_df

# %%
split_summary_df

# %% [markdown]
# ## DataLoaders

# %%
collator = DynamicPadCollator()
train_dataset = TextDataset(
    encoded_splits["train"]["encoded_ids"].tolist(),
    encoded_splits["train"]["label"].tolist(),
    encoded_splits["train"]["clean_text"].tolist(),
)
val_dataset = TextDataset(
    encoded_splits["validation"]["encoded_ids"].tolist(),
    encoded_splits["validation"]["label"].tolist(),
    encoded_splits["validation"]["clean_text"].tolist(),
)
test_dataset = TextDataset(
    encoded_splits["test"]["encoded_ids"].tolist(),
    encoded_splits["test"]["label"].tolist(),
    encoded_splits["test"]["clean_text"].tolist(),
)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collator)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collator)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collator)

pd.DataFrame({
    "split": ["train", "validation", "test"],
    "size": [len(train_dataset), len(val_dataset), len(test_dataset)],
})

# %% [markdown]
# ## Training And Evaluation

# %%
def run_epoch(model, loader, criterion, optimizer=None):
    is_train = optimizer is not None
    model.train(is_train)
    total_loss = 0.0
    total_correct = 0
    total_items = 0
    progress = tqdm(loader, leave=False, disable=not is_train)
    for input_ids, lengths, labels, _texts in progress:
        input_ids = input_ids.to(device)
        lengths = lengths.to(device)
        labels = labels.to(device)
        if is_train:
            optimizer.zero_grad()
        logits = model(input_ids, lengths)
        loss = criterion(logits, labels)
        if is_train:
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5.0)
            optimizer.step()
        batch_size = labels.size(0)
        total_loss += loss.item() * batch_size
        total_correct += int((logits.argmax(dim=1) == labels).sum().item())
        total_items += batch_size
    return total_loss / total_items, total_correct / total_items


def train_model(variant: str):
    model = RNNClassifier(
        vocab_size=len(vocab),
        embed_dim=EMBED_DIM,
        hidden_dim=HIDDEN_DIM,
        num_layers=NUM_LAYERS,
        rnn_type=variant,
        dropout=DROPOUT,
        pad_idx=PAD_ID,
    ).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
    history = []
    best_val_acc = 0.0
    checkpoint_path = CHECKPOINT_DIR / f"{variant}_best.pt"
    start_time = time.time()

    for epoch in range(1, EPOCHS + 1):
        train_loss, train_acc = run_epoch(model, train_loader, criterion, optimizer=optimizer)
        val_metrics = evaluate_loader(model, val_loader, criterion, device)
        history.append({
            "epoch": epoch,
            "train_loss": train_loss,
            "train_accuracy": train_acc,
            "val_loss": val_metrics["loss"],
            "val_accuracy": val_metrics["accuracy"],
        })
        if val_metrics["accuracy"] > best_val_acc:
            best_val_acc = val_metrics["accuracy"]
            torch.save(model.state_dict(), checkpoint_path)

    model.load_state_dict(torch.load(checkpoint_path, map_location=device))
    test_metrics = evaluate_loader(model, test_loader, criterion, device)
    history_df = pd.DataFrame(history)
    fig = plot_learning_curves(history_df, title=variant.upper())
    return {
        "model": "Vanilla RNN" if variant == "rnn" else variant.upper(),
        "variant": variant,
        "accuracy": test_metrics["accuracy"],
        "precision": test_metrics["precision"],
        "recall": test_metrics["recall"],
        "f1": test_metrics["f1"],
        "time_per_epoch_sec": (time.time() - start_time) / max(EPOCHS, 1),
        "max_len": MAX_LEN,
        "vocab_size": SELECTED_VOCAB_SIZE,
        "history_df": history_df,
        "curve_figure": fig,
        "misclassified_df": top_misclassified_examples(test_metrics["rows"]),
    }

# %%
results = [train_model(variant) for variant in ["rnn", "lstm", "gru"]]

for row in results:
    print(f"Model: {row['model']}")
    print(f"  Accuracy: {row['accuracy']:.4f}")
    print(f"  Precision: {row['precision']:.4f}")
    print(f"  Recall: {row['recall']:.4f}")
    print(f"  F1-score: {row['f1']:.4f}")
    print(f"  Time per epoch (sec): {row['time_per_epoch_sec']:.2f}")
    print(f"  Vocab size: {row['vocab_size']} | Max length: {row['max_len']}")
    print()

# %%
for row in results:
    display(row["curve_figure"])
    plt.close(row["curve_figure"])

# %%
analysis_results = [
    {key: value for key, value in row.items() if key in ["model", "variant", "accuracy", "precision", "recall", "f1", "time_per_epoch_sec"]}
    for row in results
]
analysis_results
